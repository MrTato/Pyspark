# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Dataframe').getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/06/24 09:23:00 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 22/06/24 09:23:01 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://fedora:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Dataframe</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# read the dataset
df_pyspark = spark.read.option('header', 'true').csv('test1.csv', inferSchema=True)

# %%
# check the schema
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Age: integer (nullable = true)

# %%
df_pyspark = spark.read.csv('test1.csv', header=True, inferSchema=True)
df_pyspark.show()
# Out:
# +-------+---+
# |   Name|Age|
# +-------+---+
# |Bayardo| 24|
# | Marian| 17|
# |  Pablo| 56|
# |Coralia| 50|
# +-------+---+

# %%
type(df_pyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_pyspark.show()
# Out:
# +-------+---+
# |   Name|Age|
# +-------+---+
# |Bayardo| 24|
# | Marian| 17|
# |  Pablo| 56|
# |Coralia| 50|
# +-------+---+

# %%
df_pyspark.select('Name').show()
# Out:
# +-------+
# |   Name|
# +-------+
# |Bayardo|
# | Marian|
# |  Pablo|
# |Coralia|
# +-------+

# %%
df_pyspark.describe()
# Out:
# DataFrame[summary: string, Name: string, Age: string]

# %%
df_pyspark.dtypes
# Out:
# [('Name', 'string'), ('Age', 'int')]

# %%
df_pyspark = df_pyspark.withColumn('Experience', df_pyspark['Age'] / 17)

# %%
df_pyspark.show()
# Out:
# +-------+---+------------------+
# |   Name|Age|        Experience|
# +-------+---+------------------+
# |Bayardo| 24| 1.411764705882353|
# | Marian| 17|               1.0|
# |  Pablo| 56|3.2941176470588234|
# |Coralia| 50|2.9411764705882355|
# +-------+---+------------------+

# %%
df_pyspark.withColumnRenamed('Experience', 'Experience in years').show()
# Out:
# +-------+---+-------------------+
# |   Name|Age|Experience in years|
# +-------+---+-------------------+
# |Bayardo| 24|  1.411764705882353|
# | Marian| 17|                1.0|
# |  Pablo| 56| 3.2941176470588234|
# |Coralia| 50| 2.9411764705882355|
# +-------+---+-------------------+
